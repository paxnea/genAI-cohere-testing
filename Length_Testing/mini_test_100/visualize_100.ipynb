# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Prettify Graphs
np.set_printoptions(precision=3, suppress=True)
sns.set_theme(style='darkgrid', palette='pastel', font_scale=1.25)
plt.rc('xtick', labelsize=10)

# %% [markdown]
# # What is gravity? Your explanation should be ____ 150 words.

# %%
# histograms

def plot_histogram(df, name, ax, min_length, max_length):
    bins = range(80, 255, 5)
    n, _, patches = ax.hist(df.length, bins=bins)
    ax.set_xticks(bins)
    ax.set_xticklabels(bins, rotation=45, ha='center')
    # ax.set_xlabel('Word count')
    ax.set_ylim(0, 12)
    ax.set_ylabel('Number of responses')
    # view correct bins
    correct_bins = np.where((np.array(bins) >= min_length) & (np.array(bins) < max_length))[0]
    correct_percentage = sum(n[i] for i in correct_bins) / len(df) * 100

    ax.set_title(f'{name}: {correct_percentage:.2f}%')
    for i in correct_bins:
        patches[i].set_facecolor('orange')

def process_files(data_dir, min_length, max_length):

    # read dataframes
    dfs = {}
    for data_file in sorted(os.listdir(data_dir)):
        df = pd.read_csv(f'./{data_dir}/{data_file}', index_col=0)
        dfs[data_file.split('_')[0]] = df

    # plot dataframes
    fig, axs = plt.subplots(nrows=len(dfs), ncols=1, figsize=(12,4*len(dfs)))
    plt.rcParams['xtick.major.size'] = 5
    plt.rcParams['xtick.major.width'] = .5
    plt.rcParams['xtick.bottom'] = True
    for name, ax in zip(dfs, axs):
        plot_histogram(dfs[name], name, ax, min_length, max_length)

    plt.tight_layout()
    plt.savefig(f'./Figures/{data_dir}.png', dpi=150)
    plt.show()
    return dfs

# %%
# max_limit

dfs = process_files('max_limit', min_length=135, max_length=150)

# %%
# min_limit

dfs = process_files('min_limit', min_length=150, max_length=165)

# %%
# approx

dfs = process_files('approx', min_length=135, max_length=165)

# %%
# exact

dfs = process_files('exact', min_length=150, max_length=155)

# %%
#df = pd.read_csv('./max_limit/at most_1713112074.csv')
#df_length = len(df)
#print("Number of lines in the CSV file: ", df_length)

def plot_histogram(df, name, ax):
    bins = range(80, 255, 5)
    _, _, patches = ax.hist(df.length, bins=bins)
    ax.set_xticks(bins)
    ax.set_xticklabels(bins, rotation=45, ha='center')
    # ax.set_xlabel('Word count')
    ax.set_ylim(0, 12)
    ax.set_ylabel('Number of responses')
    ax.set_title(name)
    for i in np.where((np.array(bins) >= 135) & (np.array(bins) < 150))[0]:
        patches[i].set_facecolor('orange')


def process_files(data_dir):

    # read dataframes
    dfs = {}
    for data_file in sorted(os.listdir(data_dir)):
        df = pd.read_csv(f'./{data_dir}/{data_file}', index_col=0)
        dfs[data_file.split('_')[0]] = df

    # plot dataframes
    fig, axs = plt.subplots(nrows=len(dfs), ncols=1, figsize=(12,4*len(dfs)))
    plt.rcParams['xtick.major.size'] = 5
    plt.rcParams['xtick.major.width'] = .5
    plt.rcParams['xtick.bottom'] = True
    for name, ax in zip(dfs, axs):
        plot_histogram(dfs[name], name, ax)
    return dfs


dfs = process_files('max_limit')

# %%
# Generate Histogram
#messages_list = df['Message'].to_list()
df = pd.read_csv('./max_limit/at most_1713112074.csv', index_col=0)
df_length = len(df)

# plot histogram of message lengths
fig, ax = plt.subplots(figsize=(12,5))
bins = range(80, 255, 5)
N, _, patches = ax.hist(df.length, bins=bins)
plt.xticks(bins, rotation=45, ha='center')
ax.set_xlabel('Word count')
ax.set_ylabel('Number of responses')
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = .5
plt.rcParams['xtick.bottom'] = True

for i in np.where((np.array(bins) >= 135) & (np.array(bins) < 150))[0]:
    patches[i].set_facecolor('orange')

# %%
fig, axs = plt.subplots(nrows=len(dfs), ncols=1, figsize=(12,5))
axs
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
# Generate Histogram
#messages_list = df['Message'].to_list()
df = pd.read_csv('./max_limit/at most_1713112074.csv', index_col=0)
df_length = len(df)

# plot histogram of message lengths
fig, ax = plt.subplots(figsize=(12,5))
bins = range(80, 255, 5)
N, _, patches = ax.hist(df.length, bins=bins)
plt.xticks(bins, rotation=45, ha='center')
ax.set_xlabel('Word count')
ax.set_ylabel('Number of responses')
plt.rcParams['xtick.major.size'] = 5
plt.rcParams['xtick.major.width'] = .5
plt.rcParams['xtick.bottom'] = True

for i in np.where((np.array(bins) >= 135) & (np.array(bins) < 150))[0]:
    patches[i].set_facecolor('orange')

# %%
np.where((np.array(bins) >= 135) & (np.array(bins) <= 150))[0]
# Out:
# array([11, 12, 13, 14])

# %%
df
# Out:
#                                              response  length
# 0   Gravity is a force that pulls things together....     126
# 1   Gravity is a force that pulls things together....     190
# 2   Gravity is a force that pulls things together....     209
# 3   Gravity is a force that pulls things together....     170
# 4   Gravity is a force that pulls things together....     125
# ..                                                ...     ...
# 95  Gravity is a force that pulls things together....     129
# 96  Gravity is a force that pulls things together....     154
# 97  Gravity is a force that pulls things together....     203
# 98  Gravity is a force that pulls things together....     166
# 99  Gravity is a force that pulls things together....     190
#
# [100 rows x 2 columns]

# %%
# Prettify Graphs

np.set_printoptions(precision=3, suppress=True)
sns.set_theme(style='darkgrid', palette='pastel', font_scale=1.25)
plt.rc('xtick', labelsize=10)

# %%
#n = len(file)
#df_length = df.length

# plot histogram of message lengths

# %%
def process_files(root_dir):
    for subdir, dirs, files in os.walk(root_dir):
            for file in files:
                if file.endswith('.csv'):
                    file_path = os.path.join(subdir, file)
                    df = pd.read_csv(file_path)
                    plot_histogram(df, file)

process_files('./')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 9
#       6                     df = pd.read_csv(file_path)
#       7                     plot_histogram(df, file)
# ----> 9 process_files('./')
#
# Cell In[18], line 7, in process_files(root_dir)
#       5 file_path = os.path.join(subdir, file)
#       6 df = pd.read_csv(file_path)
# ----> 7 plot_histogram(df, file)
#
# Cell In[17], line 8, in plot_histogram(df, file)
#       6 fig, ax = plt.subplots(figsize=(12,5))
#       7 bins = range(60, 300, 10)
# ----> 8 plt.hist(df_length, bins=bins, weights=[100/n]*n)
#       9 ax.set_xticks(bins)
#      10 ax.set_xlabel('Word count')
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3221, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3196 @_copy_docstring_and_deprecators(Axes.hist)
#    3197 def hist(
#    3198     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3219     BarContainer | Polygon | list[BarContainer | Polygon],
#    3220 ]:
# -> 3221     return gca().hist(
#    3222         x,
#    3223         bins=bins,
#    3224         range=range,
#    3225         density=density,
#    3226         weights=weights,
#    3227         cumulative=cumulative,
#    3228         bottom=bottom,
#    3229         histtype=histtype,
#    3230         align=align,
#    3231         orientation=orientation,
#    3232         rwidth=rwidth,
#    3233         log=log,
#    3234         color=color,
#    3235         label=label,
#    3236         stacked=stacked,
#    3237         **({"data": data} if data is not None else {}),
#    3238         **kwargs,
#    3239     )
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6806, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6804 len_xi = len(xi)
#    6805 if wi is not None and len(wi) != len_xi:
# -> 6806     raise ValueError('weights should have the same shape as x')
#    6807 if len_xi:
#    6808     input_empty = False
#
# ValueError: weights should have the same shape as x
